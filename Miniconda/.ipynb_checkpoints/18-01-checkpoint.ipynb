# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
iris_sep=np.loadtxt('data/iris_sepal.csv', delimiter=',', skiprows=1)
print( iris_sep.shape )
print( iris_sep[0:5] )
# Out:
# (150, 2)
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]

# %%
x=iris_sep[:, 0]
y=iris_sep[:, 1]
print( x.shape )
print( x[0:5] )
print( y.shape )
print( y[0:5] )
# Out:
# (150,)
# [5.1 4.9 4.7 4.6 5. ]
# (150,)
# [3.5 3.  3.2 3.1 3.6]

# %%
plt.scatter(x, y, marker='o', label='iris_sepal')
plt.xlabel('Length [cm]')
plt.ylabel('Width [cm]')
plt.legend()
plt.show()

# %%
kmcls=KMeans(n_clusters=5).fit_predict(iris_sep)
print(kmcls)
# Out:
# [2 1 1 1 2 2 1 2 1 1 2 2 1 1 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 1 1 2 2 2 1 1 2
#  1 1 2 2 1 1 2 2 1 2 1 2 2 4 0 0 3 0 3 0 1 0 1 1 3 3 3 3 0 3 3 3 3 3 3 3 3
#  0 0 0 0 3 3 3 3 3 3 3 0 0 3 3 3 3 3 3 1 3 3 3 0 1 3 0 3 4 0 0 4 1 4 0 4 0
#  0 0 3 3 0 0 4 4 3 0 3 4 0 0 4 3 3 0 4 4 4 0 0 3 4 0 0 3 0 0 0 3 0 0 0 3 0
#  0 3]

# %%
x0=x[kmcls==0]
y0=y[kmcls==0]
x1=x[kmcls==1]
y1=y[kmcls==1]
x2=x[kmcls==2]
y2=y[kmcls==2]
plt.scatter(x0, y0, marker='$0$', c='blue', label='cluster0')
plt.scatter(x1, y1, marker='$1$', c='red', label='cluster1')
plt.scatter(x2, y2, marker='$2$', c='green', label='cluster0')
plt.xlabel('Length [cm]', fontsize=15)
plt.ylabel('Width [cm]', fontsize=15)
plt.legend()
plt.show()

# %%
a = np.array( [ 0, 1, 2, 3, 4, 5 ] )
b = np.array( [ 11, 12, 13, 14, 15, 16 ] )
bb = b[ a % 2 == 0 ];  print( bb )
bb = a[ a >= 3 ];  print( bb )
# Out:
# [11 13 15]
# [3 4 5]

# %%
a = np.array( [ 0, 1, 2, 3, 4, 5 ] )
print( a % 2 == 0 )
print( a >= 3 )
# Out:
# [ True False  True False  True False]
# [False False False  True  True  True]

# %%
a = np.array( [ 0, 1, 2, 3, 4, 5 ] )
print( a[ ((a>=1) & ~(a>=4)) | (a==5) ] )
# Out:
# [1 2 3 5]

# %%
print( b[ b % 3 == 0 ] )
print( a[ b % 3 != 0 ] )
print( b[ a < 4 ] )
print( a[ a >= 4 ] )
# Out:
# [12 15]
# [0 2 3 5]
# [11 12 13 14]
# [4 5]

# %%
plt.scatter(x0, y0, marker='$0$', c='blue', label='cluster0')
plt.scatter(x1, y1, marker='$1$', c='red', label='cluster1')
plt.scatter(x2, y2, marker='$2$', c='green', label='cluster0')
plt.scatter(x3, y3, marker='$3$', c='pink', label='cluster1')
plt.scatter(x4, y4, marker='$4$', c='black', label='cluster1')
plt.xlabel('Length [cm]', fontsize=20)
plt.ylabel('Width [cm]', fontsize=20)
plt.tick_params(labelsize=20)
plt.xlim([2, 10])
plt.ylim([1, 5.5])
plt.title('Results of KMeans(2)', fontsize=20)
plt.show()
