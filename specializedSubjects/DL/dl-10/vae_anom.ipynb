# %% [markdown]
# ### Sample program for VAE anomaly detection (Dense)

# %% [markdown]
# #### Import libraries

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.losses import binary_crossentropy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import  os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' 

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
np.random.seed(29)
tf.random.set_seed(31)
# Out:
# 2021-12-01 22:56:48.424537: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-01 22:56:48.424558: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# #### Parameters

# %%
norm_digits = [8]
anom_digits = [0,2]
anom_ratio = 0.1
n_train = 4800
n_test = 800

# %% [markdown]
# #### Function for Z-sampling between encoder and decoder

# %%
# reparameterization trick
# instead of sampling from Q(z|X), sample epsilon = N(0,I)
# z = z_mean + sqrt(var) * epsilon
def sampling(args):
    """Reparameterization trick by sampling from an isotropic unit Gaussian.

    # Arguments
        args (tensor): mean and log of variance of Q(z|X)

    # Returns
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim),
                              mean=0., stddev=1. )
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# #### Function for visualization of data in latent space

# %%
def plot_results(models, data, batch_size=128):
    """Plots labels and MNIST digits as a function of the 2D latent vector

    # Arguments
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
    """

    encoder, decoder = models
    test_data, test_label = data

    # display a 2D manifold of digits
    z_mean1, _, _ = encoder.predict(test_data,
                                    batch_size=batch_size)
    plt.figure(figsize=(9, 7))
    plt.scatter(z_mean1[:, 0], z_mean1[:, 1], c=test_label)
    plt.colorbar()
    plt.xlabel("z1")
    plt.ylabel("z2")
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)
    plt.show()

    # display a 2D manifold of digits
    n = 15
    figure = np.zeros((img_h * n, img_w * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-4, 4, n)
    grid_y = np.linspace(-4, 4, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(img_h, img_w)
            figure[i * img_h: (i + 1) * img_h,
                   j * img_w: (j + 1) * img_w] = digit

    plt.figure(figsize=(7, 7))
    start_range_x = img_w // 2
    end_range_x = (n - 1) * img_w + start_range_x + 1
    pixel_range_x = np.arange(start_range_x, end_range_x, img_w)
    start_range_y = img_h // 2
    end_range_y = (n - 1) * img_h + start_range_y + 1
    pixel_range_y = np.arange(start_range_y, end_range_y, img_h)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range_x, sample_range_x)
    plt.yticks(pixel_range_y, sample_range_y)
    plt.xlabel("z1")
    plt.ylabel("z2")
    plt.imshow(figure, cmap='Greys_r')
    plt.show()

# %% [markdown]
# #### Load MNIST

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# #### Select only 0..(n_train/test_digits-1)

# %%
x_train = x_train[ np.isin(y_train, norm_digits) ]
y_train = y_train[ np.isin(y_train, norm_digits) ]
x_test_n = x_test[ np.isin(y_test, norm_digits) ]
x_test_a = x_test[ np.isin(y_test, anom_digits) ]
y_test_n = y_test[ np.isin(y_test, norm_digits) ]
y_test_a = y_test[ np.isin(y_test, anom_digits) ]
print(x_train.shape, y_train.shape)
print(x_test_n.shape, y_test_n.shape)
print(x_test_a.shape, y_test_a.shape)
# Out:
# (5851, 28, 28) (5851,)
# (974, 28, 28) (974,)
# (2012, 28, 28) (2012,)

# %% [markdown]
# #### Check the number of each label

# %%
print(pd.Series(y_train).value_counts())
print(pd.Series(y_test_n).value_counts())
print(pd.Series(y_test_a).value_counts())
# Out:
# 8    5851
# dtype: int64
# 8    974
# dtype: int64
# 2    1032
# 0     980
# dtype: int64

# %% [markdown]
# #### Reduce the number of data (for shorter calculation time)

# %%
x_train = x_train[:n_train]
y_train = y_train[:n_train]
n_test_a = int(n_test * anom_ratio)
n_test_n = n_test - n_test_a
print('n_test_n,n_test_a:', n_test_n, n_test_a)
x_test_n = x_test_n[:n_test_n]
y_test_n = y_test_n[:n_test_n]
x_test_a = x_test_a[:n_test_a]
y_test_a = y_test_a[:n_test_a]
x_test = np.vstack([x_test_n, x_test_a])
y_test = np.hstack([y_test_n, y_test_a])
idx = np.random.permutation(len(x_test))
x_test = x_test[idx]
y_test = y_test[idx]
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
print(x_test_n.shape, x_test_a.shape)
print(y_test_n.shape, y_test_a.shape)
# Out:
# n_test_n,n_test_a: 720 80
# (4800, 28, 28) (800, 28, 28)
# (4800,) (800,)
# (720, 28, 28) (80, 28, 28)
# (720,) (80,)

# %% [markdown]
# #### Check the number of each label

# %%
print(pd.Series(y_train).value_counts())
print(pd.Series(y_test).value_counts())
# Out:
# 8    4800
# dtype: int64
# 8    720
# 2     46
# 0     34
# dtype: int64

# %% [markdown]
# #### Obtain size of image

# %%
img_h = x_train.shape[1]
img_w = x_train.shape[2]
original_dim = img_h * img_w
print(img_h, img_w, original_dim)
# Out:
# 28 28 784

# %% [markdown]
# #### Re-scale data (0..1) and flatten

# %%
x_train = x_train.astype('float32') / 255
x_train = x_train.reshape(-1, original_dim)
print(x_train.shape)
x_test = x_test.astype('float32') / 255
x_test = x_test.reshape(-1, original_dim)
print(x_test.shape)
# Out:
# (4800, 784)
# (800, 784)

# %% [markdown]
# #### See images of train data

# %%
fig = plt.figure(figsize=(8, 8))  # don't move to other cell
tile_h = 5
tile_w = 5
for i in range(tile_h*tile_w):
    fig.add_subplot(tile_h, tile_w, i+1, xticks=[], yticks=[])
    plt.imshow(x_train[i].reshape((img_h, img_w)), cmap='gray')
    
plt.show()

# %% [markdown]
# #### See images of test data

# %%
fig = plt.figure(figsize=(8, 8))  # don't move to other cell
tile_h = 10
tile_w = 10
for i in range(tile_h*tile_w):
    fig.add_subplot(tile_h, tile_w, i+1, xticks=[], yticks=[])
    plt.imshow(x_test[i].reshape((img_h, img_w)), cmap='gray')
    
plt.show()
print(y_test[:tile_h*tile_w].reshape(tile_h,tile_w))
# Out:
# [[8 2 8 8 8 8 8 8 8 2]
#  [8 8 2 8 8 2 8 8 8 8]
#  [8 0 0 8 8 8 8 8 0 8]
#  [0 8 8 8 8 2 8 8 0 8]
#  [8 8 8 8 8 8 8 8 8 8]
#  [8 8 8 8 8 8 8 8 8 8]
#  [8 8 8 8 8 8 2 8 8 8]
#  [8 8 8 8 8 8 8 8 8 8]
#  [8 8 8 8 8 8 8 8 8 8]
#  [8 8 0 8 8 8 8 8 8 8]]

# %% [markdown]
# #### Start VAE calculation

# %%
K.clear_session()

# %% [markdown]
# #### Parameters for dense and latent space

# %%
input_shape = (original_dim, )
intermediate_dim = 512
latent_dim = 2

# %% [markdown]
# #### Build VAE model = encoder + decoder

# %%
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x = Dense(intermediate_dim, activation='relu')(inputs)
x = Dense(intermediate_dim, activation='relu')(x)
x = Dense(intermediate_dim, activation='relu')(x)
z_mean = Dense(latent_dim, name='z_mean')(x)
z_log_var = Dense(latent_dim, name='z_log_var')(x)

# use reparameterization trick to push the sampling out as input
z = Lambda(sampling, name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dense_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            1026        dense_2[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            1026        dense_2[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 929,284
# Trainable params: 929,284
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
x = Dense(intermediate_dim, activation='relu')(latent_inputs)
x = Dense(intermediate_dim, activation='relu')(x)
x = Dense(intermediate_dim, activation='relu')(x)
outputs = Dense(original_dim, activation='sigmoid')(x)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 2)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_6 (Dense)              (None, 784)               402192
# =================================================================
# Total params: 929,040
# Trainable params: 929,040
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Define the whole model

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])  # encoder(input)[2]: z
vae = Model(inputs, outputs, name='vae')

# %% [markdown]
# #### Function to calculate loss

# %%
def vae_loss(y_true, y_pred):
    reconstruction_loss = binary_crossentropy(y_true,
                                              y_pred)
    reconstruction_loss *= original_dim
    kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
    kl_loss = K.sum(kl_loss, axis=-1) / 2.0
    ret = K.mean(reconstruction_loss - kl_loss)
    return ret

# %% [markdown]
# #### Set optimization parameters

# %%
vae.compile(optimizer='adam', loss=vae_loss,
            experimental_run_tf_function=False)
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# encoder (Functional)         [(None, 2), (None, 2), (N 929284
# _________________________________________________________________
# decoder (Functional)         (None, 784)               929040
# =================================================================
# Total params: 1,858,324
# Trainable params: 1,858,324
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Exec learning (training)

# %%
batch_size = 32
epochs = 40
val_split = 0.1
input_data = x_train
teacher_data = x_train
input_test_data = x_test
true_test_data = x_test
true_test_label = y_test

# %%
# %%time

fit_log = vae.fit(input_data, teacher_data,
                  epochs=epochs,
                  batch_size=batch_size,
                  validation_split=val_split)
# Out:
# Train on 4320 samples, validate on 480 samples
# Epoch 1/40
# 2021-12-01 22:56:54.650425: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-01 22:56:54.650446: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-01 22:56:54.650489: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (anhvu): /proc/driver/nvidia/version does not exist
# 2021-12-01 22:56:54.650796: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 4320/4320 [==============================] - 2s 537us/sample - loss: 203.0375 - val_loss: 171.7977
# Epoch 2/40
#  192/4320 [>.............................] - ETA: 1s - loss: 169.1663
# /home/anhvu/.local/lib/python3.9/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 4320/4320 [==============================] - 2s 404us/sample - loss: 164.8559 - val_loss: 164.1761
# Epoch 3/40
# 4320/4320 [==============================] - 2s 465us/sample - loss: 160.3469 - val_loss: 163.2764
# Epoch 4/40
# 4320/4320 [==============================] - 2s 490us/sample - loss: 157.8725 - val_loss: 160.6491
# Epoch 5/40
# 4320/4320 [==============================] - 2s 476us/sample - loss: 156.7029 - val_loss: 160.2704
# Epoch 6/40
# 4320/4320 [==============================] - 2s 515us/sample - loss: 155.7260 - val_loss: 159.3765
# Epoch 7/40
# 4320/4320 [==============================] - 2s 502us/sample - loss: 155.2476 - val_loss: 159.4637
# Epoch 8/40
# 4320/4320 [==============================] - 2s 408us/sample - loss: 154.6518 - val_loss: 159.1456
# Epoch 9/40
# 4320/4320 [==============================] - 2s 439us/sample - loss: 154.3779 - val_loss: 159.4727
# Epoch 10/40
# 4320/4320 [==============================] - 2s 444us/sample - loss: 154.0023 - val_loss: 157.8468
# Epoch 11/40
# 4320/4320 [==============================] - 2s 366us/sample - loss: 153.6206 - val_loss: 158.1406
# Epoch 12/40
# 4320/4320 [==============================] - 2s 361us/sample - loss: 152.7546 - val_loss: 158.7638
# Epoch 13/40
# 4320/4320 [==============================] - 2s 430us/sample - loss: 152.5858 - val_loss: 157.9729
# Epoch 14/40
# 4320/4320 [==============================] - 2s 500us/sample - loss: 152.3419 - val_loss: 157.3462
# Epoch 15/40
# 4320/4320 [==============================] - 3s 599us/sample - loss: 152.6987 - val_loss: 159.1257
# Epoch 16/40
# 4320/4320 [==============================] - 2s 396us/sample - loss: 153.0579 - val_loss: 157.6291
# Epoch 17/40
# 4320/4320 [==============================] - 2s 361us/sample - loss: 151.6833 - val_loss: 157.2320
# Epoch 18/40
# 4320/4320 [==============================] - 2s 455us/sample - loss: 151.3405 - val_loss: 156.8182
# Epoch 19/40
# 4320/4320 [==============================] - 2s 484us/sample - loss: 150.6951 - val_loss: 155.9308
# Epoch 20/40
# 4320/4320 [==============================] - 2s 482us/sample - loss: 150.6423 - val_loss: 156.1848
# Epoch 21/40
# 4320/4320 [==============================] - 2s 479us/sample - loss: 150.3241 - val_loss: 156.2168
# Epoch 22/40
# 4320/4320 [==============================] - 2s 469us/sample - loss: 149.9098 - val_loss: 156.8428
# Epoch 23/40
# 4320/4320 [==============================] - 2s 467us/sample - loss: 149.6108 - val_loss: 154.9315
# Epoch 24/40
# 4320/4320 [==============================] - 2s 473us/sample - loss: 149.8469 - val_loss: 155.7851
# Epoch 25/40
# 4320/4320 [==============================] - 2s 473us/sample - loss: 149.6294 - val_loss: 154.5026
# Epoch 26/40
# 4320/4320 [==============================] - 2s 501us/sample - loss: 149.6294 - val_loss: 155.0554
# Epoch 27/40
# 4320/4320 [==============================] - 2s 459us/sample - loss: 149.3500 - val_loss: 155.3017
# Epoch 28/40
# 4320/4320 [==============================] - 2s 453us/sample - loss: 149.5732 - val_loss: 154.8108
# Epoch 29/40
# 4320/4320 [==============================] - 2s 473us/sample - loss: 148.5189 - val_loss: 154.3274
# Epoch 30/40
# 4320/4320 [==============================] - 2s 468us/sample - loss: 148.2639 - val_loss: 154.2293
# Epoch 31/40
# 4320/4320 [==============================] - 2s 455us/sample - loss: 148.1645 - val_loss: 155.2344
# Epoch 32/40
# 4320/4320 [==============================] - 2s 466us/sample - loss: 148.4194 - val_loss: 154.0208
# Epoch 33/40
# 4320/4320 [==============================] - 2s 464us/sample - loss: 147.7594 - val_loss: 154.0532
# Epoch 34/40
# 4320/4320 [==============================] - 2s 512us/sample - loss: 147.4578 - val_loss: 154.2260
# Epoch 35/40
# 4320/4320 [==============================] - 2s 522us/sample - loss: 147.3702 - val_loss: 154.0880
# Epoch 36/40
# 4320/4320 [==============================] - 3s 595us/sample - loss: 147.4284 - val_loss: 154.2741
# Epoch 37/40
# 4320/4320 [==============================] - 3s 598us/sample - loss: 147.1886 - val_loss: 154.4691
# Epoch 38/40
# 4320/4320 [==============================] - 3s 583us/sample - loss: 146.9710 - val_loss: 155.5730
# Epoch 39/40
# 4320/4320 [==============================] - 3s 582us/sample - loss: 149.3365 - val_loss: 155.6098
# Epoch 40/40
# 4320/4320 [==============================] - 2s 509us/sample - loss: 147.4447 - val_loss: 154.1671
# CPU times: user 5min 19s, sys: 13.7 s, total: 5min 33s
# Wall time: 1min 22s

# %% [markdown]
# #### Plot of loss/val_loss vs epochs

# %%
plt.plot(fit_log.history['loss'], label='train')
plt.plot(fit_log.history['val_loss'], label='valid')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# #### Analysis of the results

# %%
models = (encoder, decoder)
data = (input_test_data, y_test)

plot_results(models, data,
             batch_size=batch_size)

# %% [markdown]
# ##### Obtain output for test_data

# %%
pred = vae.predict(input_test_data)

# %% [markdown]
# ##### Show sample images

# %%
n = 10
plt.figure(figsize=(12, 4))
for i in range(n):
    # Show input test image
    ax = plt.subplot(3, n, i+1)
    plt.imshow(input_test_data[i].reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
 
    # Show output test image
    ax = plt.subplot(3, n, i+1+n)
    plt.imshow(pred[i].reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Obtain diff between images
    diff_img = true_test_data[i] - pred[i]
    
    # Obtain total value of diff between images  
    diff_score = np.sum(np.abs(true_test_data[i]-pred[i]))
        
    # Show results  
    ax = plt.subplot(3, n, i+1+n*2)
    plt.imshow(diff_img.reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False) 
    ax.set_xlabel('score:{:.2f}'.format(diff_score), fontsize=8)    
    
plt.show()

# %% [markdown]
# ##### Show distribution of scores

# %%
diff_scores = []
diff_labels = []
for i in range(len(input_test_data)):   
    # Obtain total value of diff between images  
    diff_score = np.sum(np.abs(true_test_data[i]-pred[i]))
    diff_scores.append(diff_score)
    diff_labels.append(true_test_label[i])

diff_scores = np.array(diff_scores)
diff_labels = np.array(diff_labels)

for i in norm_digits+anom_digits:
    plt.hist(diff_scores[ diff_labels==i ], label=str(i), density=True, alpha=0.2)
plt.xlabel('Scores')
plt.ylabel('Prob')
plt.legend()
plt.show()

# %%
for i in norm_digits+anom_digits:
    print(i, np.mean(diff_scores[ diff_labels==i ]))
# Out:
# 8 74.1478
# 0 120.843864
# 2 113.04893
