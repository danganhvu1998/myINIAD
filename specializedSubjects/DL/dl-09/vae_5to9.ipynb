# %% [markdown]
# ### Sample program for VAE

# %% [markdown]
# #### Import libraries

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.losses import binary_crossentropy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import  os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' 

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
np.random.seed(11)
tf.random.set_seed(13)

# %% [markdown]
# #### Parameters

# %%
n_digits = 5
n_train = 4800
n_test = 800

# %% [markdown]
# #### Function for Z-sampling between encoder and decoder

# %%
# reparameterization trick
# instead of sampling from Q(z|X), sample epsilon = N(0,I)
# z = z_mean + sqrt(var) * epsilon
def sampling(args):
    """Reparameterization trick by sampling from an isotropic unit Gaussian.

    # Arguments
        args (tensor): mean and log of variance of Q(z|X)

    # Returns
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim),
                              mean=0., stddev=1. )
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# #### Function for visualization of data in latent space

# %%
def plot_results(models, data, batch_size=128):
    """Plots labels and MNIST digits as a function of the 2D latent vector

    # Arguments
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
    """

    encoder, decoder = models
    test_data, test_label = data

    # display a 2D manifold of digits
    z_mean1, _, _ = encoder.predict(test_data,
                                   batch_size=batch_size)
    plt.figure(figsize=(9, 7))
    plt.scatter(z_mean1[:, 0], z_mean1[:, 1], c=test_label)
    plt.colorbar()
    plt.xlabel("z1")
    plt.ylabel("z2")
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)
    plt.show()

    # display a 2D manifold of digits
    n = 15
    figure = np.zeros((img_h * n, img_w * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-4, 4, n)
    grid_y = np.linspace(-4, 4, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(img_h, img_w)
            figure[i * img_h: (i + 1) * img_h,
                   j * img_w: (j + 1) * img_w] = digit

    plt.figure(figsize=(7, 7))
    start_range_x = img_w // 2
    end_range_x = (n - 1) * img_w + start_range_x + 1
    pixel_range_x = np.arange(start_range_x, end_range_x, img_w)
    start_range_y = img_h // 2
    end_range_y = (n - 1) * img_h + start_range_y + 1
    pixel_range_y = np.arange(start_range_y, end_range_y, img_h)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range_x, sample_range_x)
    plt.yticks(pixel_range_y, sample_range_y)
    plt.xlabel("z1")
    plt.ylabel("z2")
    plt.imshow(figure, cmap='Greys_r')
    plt.show()

# %% [markdown]
# #### Load MNIST

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# #### Select only 0..(n_digits-1)

# %%
x_train = x_train[ y_train >= n_digits ]
y_train = y_train[ y_train >= n_digits ]
x_test = x_test[ y_test >= n_digits ]
y_test = y_test[ y_test >= n_digits ]
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (29404, 28, 28) (29404,)
# (4861, 28, 28) (4861,)

# %% [markdown]
# #### Check the number of each label

# %%
print(pd.Series(y_train).value_counts())
print(pd.Series(y_test).value_counts())
# Out:
# 7    6265
# 9    5949
# 6    5918
# 8    5851
# 5    5421
# dtype: int64
# 7    1028
# 9    1009
# 8     974
# 6     958
# 5     892
# dtype: int64

# %% [markdown]
# #### Reduce the number of data (for shorter calculation time)

# %%
x_train = x_train[:n_train]
y_train = y_train[:n_train]
x_test = x_test[:n_test]
y_test = y_test[:n_test]
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (4800, 28, 28) (800, 28, 28)
# (4800,) (800,)

# %% [markdown]
# #### Check the number of each label

# %%
print(pd.Series(y_train).value_counts())
print(pd.Series(y_test).value_counts())
# Out:
# 7    1054
# 6     999
# 9     965
# 8     927
# 5     855
# dtype: int64
# 7    169
# 9    167
# 8    163
# 5    154
# 6    147
# dtype: int64

# %% [markdown]
# #### Obtain size of image

# %%
img_h = x_train.shape[1]
img_w = x_train.shape[2]
original_dim = img_h * img_w
print(img_h, img_w, original_dim)
# Out:
# 28 28 784

# %% [markdown]
# #### Re-scale data (0..1) and flatten

# %%
x_train = x_train.astype('float32') / 255
x_train = x_train.reshape(-1, original_dim)
print(x_train.shape)
x_test = x_test.astype('float32') / 255
x_test = x_test.reshape(-1, original_dim)
print(x_test.shape)
# Out:
# (4800, 784)
# (800, 784)

# %% [markdown]
# #### See images

# %%
fig = plt.figure(figsize=(8, 8))  # don't move to other cell
tile_h = 5
tile_w = 5
for i in range(tile_h*tile_w):
    fig.add_subplot(tile_h, tile_w, i+1, xticks=[], yticks=[])
    plt.imshow(x_train[i].reshape((img_h, img_w)), cmap='gray')
    
plt.show()

# %% [markdown]
# #### Start VAE calculation

# %%
K.clear_session()

# %% [markdown]
# #### Parameters for dense and latent space

# %%
input_shape = (original_dim, )
# intermediate_dim = 512
# latent_dim = 2
intermediate_dim = 64
latent_dim = 2

# %% [markdown]
# #### Build VAE model = encoder + decoder

# %%
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x = Dense(intermediate_dim, activation='relu')(inputs)
# x = Dense(intermediate_dim, activation='relu')(x)
# x = Dense(intermediate_dim, activation='relu')(x)
z_mean = Dense(latent_dim, name='z_mean')(x)
z_log_var = Dense(latent_dim, name='z_log_var')(x)

# use reparameterization trick to push the sampling out as input
z = Lambda(sampling, name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           50240       encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            130         dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            130         dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 50,500
# Trainable params: 50,500
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
x = Dense(intermediate_dim, activation='relu')(latent_inputs)
# x = Dense(intermediate_dim, activation='relu')(x)
# x = Dense(intermediate_dim, activation='relu')(x)
outputs = Dense(original_dim, activation='sigmoid')(x)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               50960
# =================================================================
# Total params: 51,152
# Trainable params: 51,152
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Define the whole model

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])  # encoder(input)[2]: z
vae = Model(inputs, outputs, name='vae')

# %% [markdown]
# #### Function to calculate loss

# %%
def vae_loss(y_true, y_pred):
    reconstruction_loss = binary_crossentropy(y_true,
                                              y_pred)
    reconstruction_loss *= original_dim
    kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
    kl_loss = K.sum(kl_loss, axis=-1) / 2
    ret = K.mean(reconstruction_loss - kl_loss)
    return ret

# %% [markdown]
# #### Set optimization parameters

# %%
vae.compile(optimizer='adam', loss=vae_loss,
            experimental_run_tf_function=False)
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# encoder (Functional)         [(None, 2), (None, 2), (N 50500
# _________________________________________________________________
# decoder (Functional)         (None, 784)               51152
# =================================================================
# Total params: 101,652
# Trainable params: 101,652
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Exec learning (training)

# %%
batch_size = 32
epochs = 40
val_split = 0.1
input_data = x_train
teacher_data = x_train
input_test_data = x_test
true_test_data = x_test
true_test_label = y_test

# %%
# %%time

fit_log = vae.fit(input_data, teacher_data,
                  epochs=epochs,
                  batch_size=batch_size,
                  validation_split=val_split)
# Out:
# Train on 4320 samples, validate on 480 samples
# Epoch 1/40
# 4320/4320 [==============================] - 0s 112us/sample - loss: 285.5132 - val_loss: 214.9085
# Epoch 2/40
# 4320/4320 [==============================] - 0s 72us/sample - loss: 203.0878 - val_loss: 191.6868
# Epoch 3/40
# 4320/4320 [==============================] - 0s 71us/sample - loss: 188.1621 - val_loss: 182.0434
# Epoch 4/40
# 4320/4320 [==============================] - 0s 67us/sample - loss: 180.5513 - val_loss: 176.6294
# Epoch 5/40
# 4320/4320 [==============================] - 0s 66us/sample - loss: 175.8623 - val_loss: 172.6697
# Epoch 6/40
# 4320/4320 [==============================] - 0s 67us/sample - loss: 172.1000 - val_loss: 170.2445
# Epoch 7/40
# 4320/4320 [==============================] - 0s 64us/sample - loss: 169.3114 - val_loss: 166.5102
# Epoch 8/40
# 4320/4320 [==============================] - 0s 66us/sample - loss: 166.9941 - val_loss: 164.4134
# Epoch 9/40
# 4320/4320 [==============================] - 0s 66us/sample - loss: 165.2527 - val_loss: 162.9655
# Epoch 10/40
# 4320/4320 [==============================] - 0s 65us/sample - loss: 163.8621 - val_loss: 162.1780
# Epoch 11/40
# 4320/4320 [==============================] - 0s 66us/sample - loss: 162.8637 - val_loss: 161.0692
# Epoch 12/40
# 4320/4320 [==============================] - 0s 66us/sample - loss: 161.9371 - val_loss: 160.4307
# Epoch 13/40
# 4320/4320 [==============================] - 0s 79us/sample - loss: 161.2597 - val_loss: 159.9755
# Epoch 14/40
# 4320/4320 [==============================] - 0s 83us/sample - loss: 160.5674 - val_loss: 159.7844
# Epoch 15/40
# 4320/4320 [==============================] - 0s 89us/sample - loss: 160.0132 - val_loss: 159.1240
# Epoch 16/40
# 4320/4320 [==============================] - 0s 88us/sample - loss: 159.5638 - val_loss: 158.4300
# Epoch 17/40
# 4320/4320 [==============================] - 0s 102us/sample - loss: 159.1003 - val_loss: 158.7734
# Epoch 18/40
# 4320/4320 [==============================] - 0s 100us/sample - loss: 158.7303 - val_loss: 158.5614
# Epoch 19/40
# 4320/4320 [==============================] - 0s 85us/sample - loss: 158.2793 - val_loss: 158.5134
# Epoch 20/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 157.9812 - val_loss: 158.2389
# Epoch 21/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 157.6863 - val_loss: 157.9973
# Epoch 22/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 157.2774 - val_loss: 157.2007
# Epoch 23/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 157.0328 - val_loss: 157.3342
# Epoch 24/40
# 4320/4320 [==============================] - 0s 81us/sample - loss: 156.6943 - val_loss: 157.3938
# Epoch 25/40
# 4320/4320 [==============================] - 0s 75us/sample - loss: 156.4685 - val_loss: 156.8854
# Epoch 26/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 156.2647 - val_loss: 157.3715
# Epoch 27/40
# 4320/4320 [==============================] - 0s 83us/sample - loss: 155.8531 - val_loss: 156.8249
# Epoch 28/40
# 4320/4320 [==============================] - 0s 81us/sample - loss: 155.6530 - val_loss: 156.3656
# Epoch 29/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 155.4468 - val_loss: 156.4206
# Epoch 30/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 155.1971 - val_loss: 156.1680
# Epoch 31/40
# 4320/4320 [==============================] - 0s 83us/sample - loss: 154.9676 - val_loss: 155.7438
# Epoch 32/40
# 4320/4320 [==============================] - 0s 83us/sample - loss: 154.8376 - val_loss: 155.3942
# Epoch 33/40
# 4320/4320 [==============================] - 0s 97us/sample - loss: 154.6236 - val_loss: 155.5515
# Epoch 34/40
# 4320/4320 [==============================] - 0s 82us/sample - loss: 154.3980 - val_loss: 155.4280
# Epoch 35/40
# 4320/4320 [==============================] - 0s 81us/sample - loss: 154.1832 - val_loss: 155.4840
# Epoch 36/40
# 4320/4320 [==============================] - 0s 78us/sample - loss: 153.9307 - val_loss: 155.0457
# Epoch 37/40
# 4320/4320 [==============================] - 0s 77us/sample - loss: 153.7696 - val_loss: 154.9633
# Epoch 38/40
# 4320/4320 [==============================] - 0s 77us/sample - loss: 153.6734 - val_loss: 154.9788
# Epoch 39/40
# 4320/4320 [==============================] - 0s 77us/sample - loss: 153.5170 - val_loss: 154.1708
# Epoch 40/40
# 4320/4320 [==============================] - 0s 77us/sample - loss: 153.2189 - val_loss: 154.7591
# CPU times: user 32.8 s, sys: 3.5 s, total: 36.3 s
# Wall time: 14 s

# %% [markdown]
# #### Plot of loss/val_loss vs epochs

# %%
plt.plot(fit_log.history['loss'], label='train')
plt.plot(fit_log.history['val_loss'], label='valid')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# #### Analysis of the results

# %%
models = (encoder, decoder)
data = (input_test_data, y_test)

plot_results(models, data,
             batch_size=batch_size)

# %% [markdown]
# ##### Obtain output for test_data

# %%
pred = vae.predict(input_test_data)

# %% [markdown]
# ##### Show sample images

# %%
n = 10
plt.figure(figsize=(12, 4))
for i in range(n):
    # Show input test image
    ax = plt.subplot(3, n, i+1)
    plt.imshow(input_test_data[i].reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
 
    # Show output test image
    ax = plt.subplot(3, n, i+1+n)
    plt.imshow(pred[i].reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Obtain diff between images
    diff_img = true_test_data[i] - pred[i]
    
    # Obtain total value of diff between images  
    diff_score1 = np.sum(np.abs(true_test_data[i]-pred[i]))
        
    # Show results  
    ax = plt.subplot(3, n, i+1+n*2)
    plt.imshow(diff_img.reshape(img_h, img_w))
    plt.gray()
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False) 
    ax.set_xlabel('score:{:.2f}'.format(diff_score1), fontsize=8)    
    
plt.show()

# %% [markdown]
# ##### Show distribution of scores

# %%
diff_scores = []
diff_labels = []
for i in range(len(input_test_data)):   
    # Obtain total value of diff between images  
    diff_score = np.sum(np.abs(true_test_data[i]-pred[i]))
    diff_scores.append(diff_score)
    diff_labels.append(true_test_label[i])

diff_scores = np.array(diff_scores)
diff_labels = np.array(diff_labels)

for i in range(5, 10):
    plt.hist(diff_scores[ diff_labels==i ], label=str(i), density=True, alpha=0.2)
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.legend()
plt.show()
